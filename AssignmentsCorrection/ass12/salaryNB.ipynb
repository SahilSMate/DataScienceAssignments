# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
salary_test = pd.read_csv('SalaryData_Test.csv')
salary_train = pd.read_csv('SalaryData_Train.csv')
salary_train
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
salary_train.shape
# Out:
# (30161, 14)

# %%
salary_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
salary_train.describe().T
# Out:
#                 count         mean          std   min   25%   50%   75%  \
# age           30161.0    38.438115    13.134830  17.0  28.0  37.0  47.0
# educationno   30161.0    10.121316     2.550037   1.0   9.0  10.0  13.0
# capitalgain   30161.0  1092.044064  7406.466611   0.0   0.0   0.0   0.0
# capitalloss   30161.0    88.302311   404.121321   0.0   0.0   0.0   0.0
# hoursperweek  30161.0    40.931269    11.980182   1.0  40.0  40.0  45.0
#
#                   max
# age              90.0
# educationno      16.0
# capitalgain   99999.0
# capitalloss    4356.0
# hoursperweek     99.0

# %%
sns.histplot(salary_train['educationno'])
# Out:
# <AxesSubplot:xlabel='educationno', ylabel='Count'>

# %%
sns.boxplot(salary_train['educationno'])
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='educationno'>

# %%
pd.crosstab(salary_train['sex'],salary_train['Salary']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
pd.crosstab(salary_train['race'],salary_train['Salary']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='race'>

# %%
pd.crosstab(salary_train['sex'],salary_train['race'])
# Out:
# race    0    1     2    3      4
# sex
# 0     107  294  1399   87   7894
# 1     179  601  1418  144  18038

# %%
pd.crosstab(salary_train['relationship'],salary_train['Salary']).plot(kind='bar')
#Most of Not-in-family, Own-child, Unmarried have salary less than 50K
# Out:
# <AxesSubplot:xlabel='relationship'>

# %%
pd.crosstab(salary_train['occupation'],salary_train['Salary'])
# Out:
# Salary               <=50K   >50K
# occupation
#  Adm-clerical         3223    498
#  Armed-Forces            8      1
#  Craft-repair         3122    908
#  Exec-managerial      2055   1937
#  Farming-fishing       874    115
#  Handlers-cleaners    1267     83
#  Machine-op-inspct    1720    245
#  Other-service        3080    132
#  Priv-house-serv       142      1
#  Prof-specialty       2227   1811
#  Protective-serv       434    210
#  Sales                2614    970
#  Tech-support          634    278
#  Transport-moving     1253    319

# %%
pd.crosstab(salary_train['workclass'],salary_train['Salary'])
# Out:
# Salary              <=50K   >50K
# workclass
#  Federal-gov          578    365
#  Local-gov           1458    609
#  Private            17409   4876
#  Self-emp-inc         474    600
#  Self-emp-not-inc    1785    714
#  State-gov            935    344
#  Without-pay           14      0

# %%
pd.crosstab(salary_train['workclass'],salary_train['Salary']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='workclass'>

# %%
pd.crosstab(salary_train['education'],salary_train['Salary'])
# Out:
# Salary          <=50K   >50K
# education
#  10th             761     59
#  11th             989     59
#  12th             348     29
#  1st-4th          145      6
#  5th-6th          276     12
#  7th-8th          522     35
#  9th              430     25
#  Assoc-acdm       752    256
#  Assoc-voc        963    344
#  Bachelors       2918   2126
#  Doctorate         95    280
#  HS-grad         8223   1617
#  Masters          709    918
#  Preschool         45      0
#  Prof-school      136    406
#  Some-college    5341   1336

# %%
pd.crosstab(salary_train['education'],salary_train['Salary']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='education'>

# %%
pd.crosstab(salary_train['hoursperweek'],salary_train['Salary'])
# Out:
# Salary         <=50K   >50K
# hoursperweek
# 1                  6      1
# 2                 13      2
# 3                 23      1
# 4                 25      2
# 5                 32      6
# ...              ...    ...
# 95                 1      1
# 96                 4      1
# 97                 1      1
# 98                 8      3
# 99                53     25
#
# [94 rows x 2 columns]

# %%
pd.crosstab(salary_train['native'],salary_train['Salary'])
# Out:
# Salary                        <=50K   >50K
# native
#  Cambodia                        11      7
#  Canada                          71     36
#  China                           48     20
#  Columbia                        54      2
#  Cuba                            67     25
#  Dominican-Republic              65      2
#  Ecuador                         23      4
#  El-Salvador                     91      9
#  England                         56     30
#  France                          15     12
#  Germany                         84     44
#  Greece                          21      8
#  Guatemala                       60      3
#  Haiti                           38      4
#  Honduras                        11      1
#  Hong                            13      6
#  Hungary                         10      3
#  India                           60     40
#  Iran                            24     18
#  Ireland                         19      5
#  Italy                           44     24
# ...

# %%
salary_train.groupby(['sex']).mean()
# Out:
#                age  educationno  capitalgain  capitalloss  hoursperweek
# sex
#  Female  36.883959    10.098661   570.235048    60.719558     36.931909
#  Male    39.184004    10.132188  1342.476546   101.540137     42.850687

# %%
salary_train.groupby(['race']).mean()
# Out:
#                            age  educationno  capitalgain  capitalloss  \
# race
#  Amer-Indian-Eskimo  36.737762     9.356643   660.290210    37.164336
#  Asian-Pac-Islander  37.910615    11.025698  1304.375419    91.683799
#  Black               37.860845     9.530706   604.722045    56.267661
#  Other               33.601732     8.683983  1060.653680    50.294372
#  White               38.580865    10.175497  1142.695087    92.568101
#
#                      hoursperweek
# race
#  Amer-Indian-Eskimo     40.426573
#  Asian-Pac-Islander     40.500559
#  Black                  38.674476
#  Other                  40.112554
#  White                  41.204149

# %%
salary_train.groupby(['native']).mean()
# Out:
#                                    age  educationno  capitalgain  capitalloss  \
# native
#  Cambodia                    38.888889     8.722222  1084.944444   104.222222
#  Canada                      41.514019    10.672897  1614.560748   146.934579
#  China                       42.235294    11.235294   404.205882   198.000000
#  Columbia                    39.339286     9.446429   190.285714    28.607143
#  Cuba                        45.532609     9.695652   379.206522    72.326087
#  Dominican-Republic          37.432836     7.089552  1542.149254    26.298507
#  Ecuador                     36.444444     9.555556   547.148148     0.000000
#  El-Salvador                 34.720000     6.880000   608.780000    15.790000
#  England                     41.255814    11.127907   904.941860    86.604651
#  France                      39.888889    12.370370   587.555556     0.000000
#  Germany                     39.695312    11.109375   949.468750    83.460938
# ...

# %%
import seaborn as sns
sns.boxplot(salary_train['hoursperweek'])
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='hoursperweek'>

# %%
salary_train.shape
# Out:
# (30161, 14)

# %%
outll = np.where(salary_train['hoursperweek']<30)
outll = np.array(outll).tolist()
outll
# Out:
# [[1,
#   6,
#   20,
#   32,
#   35,
#   68,
#   71,
#   85,
#   104,
#   117,
#   128,
#   136,
#   137,
#   145,
#   155,
#   156,
#   162,
#   165,
#   175,
#   176,
#   180,
#   194,
#   207,
#   211,
#   224,
#   234,
#   242,
#   250,
#   259,
#   274,
#   279,
#   291,
#   296,
#   301,
#   319,
#   322,
#   323,
#   333,
#   340,
#   343,
#   344,
#   348,
#   358,
#   360,
#   361,
#   378,
#   380,
#   387,
#   391,
#   401,
#   409,
#   429,
#   434,
#   438,
#   440,
#   445,
#   446,
#   448,
#   455,
#   456,
#   467,
#   475,
#   484,
#   502,
#   527,
#   538,
#   551,
#   559,
#   564,
#   570,
#   571,
#   572,
#   579,
#   585,
#   597,
#   599,
#   612,
#   618,
#   622,
#   630,
#   638,
#   639,
#   643,
#   653,
#   661,
#   669,
#   671,
#   674,
#   678,
#   680,
#   684,
#   691,
#   700,
#   713,
#   730,
#   737,
#   739,
#   747,
#   760,
#   761,
#   770,
#   771,
#   780,
#   791,
#   796,
#   798,
#   805,
#   807,
#   816,
#   829,
#   834,
#   835,
# ...

# %%
outlh = np.where(salary_train['hoursperweek']>52)
outlh = np.array(outlh).tolist()

# %%
data = salary_train.copy()
data = data.drop(index=outll[0])

# %%
data.shape
# Out:
# (26767, 14)

# %%
data = data.drop(index=outlh[0])

# %%
data.shape
# Out:
# (23440, 14)

# %%
salary_train.columns
salary_test.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
string_columns=['workclass','education','maritalstatus','occupation','relationship','race','sex','native']

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
for i in string_columns:
    salary_train[i]=label_encoder.fit_transform(salary_train[i])
    salary_test[i]=label_encoder.fit_transform(salary_test[i])

# %%
col_names=list(salary_train.columns)
train_X=salary_train[col_names[0:13]]
train_Y=salary_train[col_names[13]]
test_x=salary_test[col_names[0:13]]
test_y=salary_test[col_names[13]]

# %%
from sklearn.naive_bayes import GaussianNB
Gmodel=GaussianNB()
train_pred_gau=Gmodel.fit(train_X,train_Y).predict(train_X)
test_pred_gau=Gmodel.fit(train_X,train_Y).predict(test_x)

train_acc_gau=np.mean(train_pred_gau==train_Y)
test_acc_gau=np.mean(test_pred_gau==test_y)

# %%
train_acc_gau
# Out:
# 0.7953317197705646

# %%
test_acc_gau
# Out:
# 0.7946879150066402

# %%
print(classification_report(test_y, test_pred_gau))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.81      0.95      0.87     11360
#         >50K       0.67      0.33      0.44      3700
#
#     accuracy                           0.79     15060
#    macro avg       0.74      0.64      0.66     15060
# weighted avg       0.78      0.79      0.77     15060

# %%
from sklearn.naive_bayes import MultinomialNB
Mmodel=MultinomialNB()
train_pred_multi=Mmodel.fit(train_X,train_Y).predict(train_X)
test_pred_multi=Mmodel.fit(train_X,train_Y).predict(test_x)

train_acc_multi=np.mean(train_pred_multi==train_Y)
test_acc_multi=np.mean(test_pred_multi==test_y)

# %%
train_acc_multi
# Out:
# 0.7729186698053778

# %%
test_acc_multi
# Out:
# 0.7749667994687915

# %%
print(classification_report(test_y, test_pred_multi))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.79      0.96      0.87     11360
#         >50K       0.62      0.21      0.32      3700
#
#     accuracy                           0.77     15060
#    macro avg       0.71      0.58      0.59     15060
# weighted avg       0.75      0.77      0.73     15060

# %%
label_encoder=preprocessing.LabelEncoder()
for i in string_columns:
    data[i]=label_encoder.fit_transform(data[i])

# %%
col_names=list(salary_train.columns)
train_Xd=data[col_names[0:13]]
train_Yd=data[col_names[13]]

# %%
train_pred_gaud=Gmodel.fit(train_Xd,train_Yd).predict(train_Xd)
test_pred_gaud=Gmodel.fit(train_Xd,train_Yd).predict(test_x)

train_acc_gaud=np.mean(train_pred_gaud==train_Yd)
test_acc_gaud=np.mean(test_pred_gaud==test_y)

# %%
train_acc_gaud
# Out:
# 0.7903156996587031

# %%
test_acc_gaud
# Out:
# 0.7906374501992032

# %%
from sklearn.metrics import classification_report,confusion_matrix
cm = confusion_matrix(test_y, test_pred_gaud)  

print(cm)
# Out:
# [[10416   944]
#  [ 2209  1491]]

# %%
print(classification_report(test_y, test_pred_gaud))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.83      0.92      0.87     11360
#         >50K       0.61      0.40      0.49      3700
#
#     accuracy                           0.79     15060
#    macro avg       0.72      0.66      0.68     15060
# weighted avg       0.77      0.79      0.77     15060
